# %%
import pandas as pd

from regression import UnivariateLinearRegression

training_dataset = pd.read_csv('datasets/train.csv')
test_dataset = pd.read_csv('datasets/test.csv')
display(training_dataset)
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
linear_regression = UnivariateLinearRegression(training_dataset)
linear_regression.train()
# Out:
# Calculating gradients for iteration  999
# Cost after 999  iterations =  0.004649234990682319
# Weights after 999  iterations =  0   -2.498240e-16
# 1    9.952965e-01
# dtype: float64
# Cost after 999  iterations =  0.00464923497193735
# Weights after 999  iterations =  0   -2.498240e-16
# 1    9.952969e-01
# dtype: float64
# 0   -2.498240e-16
# 1    9.952969e-01
# dtype: float64

# %%
linear_regression.calculate_accuracy_r2(test_dataset['x'], test_dataset['y'])
# Out:
# 0.9883886222259362

# %%
y_predicted = linear_regression.predict(test_dataset['x'])
linear_regression.plot_trained_model(training_dataset['x'], training_dataset['y'])
linear_regression.plot_trained_model(test_dataset['x'], test_dataset['y'])
